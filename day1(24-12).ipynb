# %% [markdown]
# # WELCOME TO PYTHON

# %% [markdown]
# ## PYTHON IS VERY POPULAR

# %% [markdown]
# #R
# ##A
# ###V
# ####A
# #####L
# ######I

# %% [markdown]
# # R
#
# ## A
#
# ### V
#
# #### A
#
# ##### L
#
# ###### I

# %% [markdown]
# ###### R
#
# ##### A
#
# #### V
#
# ### A
#
# ## L
#
# # I

# %% [markdown]
# # TO INSERT AN IMAGE
# ![]()
# ![TITLE](data:image/jpeg;base64,...))

# %% [markdown]
# # USE *TEXT* FOR GETTING ITALIC
# # **TEXT**
# # ***TEXT***

# %% [markdown]
# <FONT COLOR="BLUE">GITAM</FONT>

# %% [markdown]
# <A HREF="https://www.gitam.edu/">CLICK ME</A>

# %% [markdown]
#  <OL>
# <LI>HYD</LI>
# <LI>VIZAG</LI>
# <LI>BANGLORE</LI>
# </OL>

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
a=10
b=34.2
c="hyh"
d='khk'
print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 34.2
# hyh
# khk
